# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import time
import numpy as np
import copy
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy.integrate import solve_ivp
# !pip install tikzplotlib #uncomment for saving nice images
import tikzplotlib
from pylab import *
# set precision
torch.set_default_dtype(torch.float64)
print('Default data type:', torch.get_default_dtype())
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tikzplotlib
#   Downloading tikzplotlib-0.10.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 KB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from tikzplotlib) (3.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from tikzplotlib) (8.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from tikzplotlib) (1.22.4)
# Collecting webcolors
#   Downloading webcolors-1.12-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=1.4.0->tikzplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->tikzplotlib) (1.15.0)
# Installing collected packages: webcolors, tikzplotlib
# Successfully installed tikzplotlib-0.10.1 webcolors-1.12
# Default data type: torch.float64

# %%
import os, torch, pickle, zipfile, sys
import imageio, shutil
import scipy, scipy.misc, scipy.integrate
solve_ivp = scipy.integrate.solve_ivp

# %%
# !pip install hessquik
import hessQuik.activations as act
import hessQuik.layers as lay
import hessQuik.networks as net
from hessQuik.utils import  test
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hessquik
#   Downloading hessQuik-0.0.2-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 KB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from hessquik) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->hessquik) (4.5.0)
# Installing collected packages: hessquik
# Successfully installed hessquik-0.0.2

# %%
'''
Create dataset for models: functions for the different energies, dynamics, bodies, and their orbits

  Code from:
  Hamiltonian Neural Networks | 2019
  Sam Greydanus, Misko Dzamba, Jason Yosinski
https://github.com/greydanus/hamiltonian-nn/blob/master/experiment-2body/data.py
'''


def to_pickle(thing, path): # save something
    with open(path, 'wb') as handle:
        pickle.dump(thing, handle, protocol=pickle.HIGHEST_PROTOCOL)


def from_pickle(path): # load something
    thing = None
    with open(path, 'rb') as handle:
        thing = pickle.load(handle)
    return thing

##### ENERGY #####
def potential_energy(state):
    '''U=sum_i,j>i G m_i m_j / r_ij'''
    tot_energy = np.zeros((1,1,state.shape[2]))
    for i in range(state.shape[0]):
        for j in range(i+1,state.shape[0]):
            r_ij = ((state[i:i+1,1:3] - state[j:j+1,1:3])**2).sum(1, keepdims=True)**.5
            m_i = state[i:i+1,0:1]
            m_j = state[j:j+1,0:1]
    tot_energy += m_i * m_j / r_ij
    U = -tot_energy.sum(0).squeeze()
    return U

def kinetic_energy(state):
    '''T=sum_i .5*m*v^2'''
    energies = .5 * state[:,0:1] * (state[:,3:5]**2).sum(1, keepdims=True)
    T = energies.sum(0).squeeze()
    return T

def total_energy(state):
    return potential_energy(state) + kinetic_energy(state)


##### DYNAMICS #####
def get_accelerations(state, epsilon=0):
    # shape of state is [bodies x properties]
    net_accs = [] # [nbodies x 2]
    for i in range(state.shape[0]): # number of bodies
        other_bodies = np.concatenate([state[:i, :], state[i+1:, :]], axis=0)
        displacements = other_bodies[:, 1:3] - state[i, 1:3] # indexes 1:3 -> pxs, pys
        distances = (displacements**2).sum(1, keepdims=True)**0.5
        masses = other_bodies[:, 0:1] # index 0 -> mass
        pointwise_accs = masses * displacements / (distances**3 + epsilon) # G=1
        net_acc = pointwise_accs.sum(0, keepdims=True)
        net_accs.append(net_acc)
    net_accs = np.concatenate(net_accs, axis=0)
    return net_accs
  
def update(t, state):
    state = state.reshape(-1,5) # [bodies, properties]
    deriv = np.zeros_like(state)
    deriv[:,1:3] = state[:,3:5] # dx, dy = vx, vy
    deriv[:,3:5] = get_accelerations(state)
    return deriv.reshape(-1)


##### INTEGRATION SETTINGS #####
#this is the function we will be using to get our data for the two bodies 
def get_orbit(state, update_fn=update, t_points=100, t_span=[0,2], **kwargs):
    if not 'rtol' in kwargs.keys():
        kwargs['rtol'] = 1e-9

    orbit_settings = locals() #creates a dictionary of the local variables

    nbodies = state.shape[0]
    t_eval = np.linspace(t_span[0], t_span[1], t_points)
    orbit_settings['t_eval'] = t_eval

    path = solve_ivp(fun=update_fn, t_span=t_span, y0=state.flatten(),
                     t_eval=t_eval, **kwargs)
    orbit = path['y'].reshape(nbodies, 5, t_points)
    #returns orbit: 3D array, for us 2 bodies, 5 values, for each timestep
    # and orbit_settings: dictionary of local vars, state, update_fn, t_points, t_span, kwargs, t_eval
    return orbit, orbit_settings


##### INITIALIZE THE TWO BODIES #####
def random_config(orbit_noise=5e-2, min_radius=0.5, max_radius=1.5):
    state = np.zeros((2,5))
    state[:,0] = 1
    pos = np.random.rand(2) * (max_radius-min_radius) + min_radius
    r = np.sqrt( np.sum((pos**2)) )

    # velocity that yields a circular orbit
    vel = np.flipud(pos) / (2 * r**1.5)
    vel[0] *= -1
    vel *= 1 + orbit_noise*np.random.randn()

    # make the circular orbits SLIGHTLY elliptical
    state[:,1:3] = pos
    state[:,3:5] = vel
    state[1,1:] *= -1
    return state


##### HELPER FUNCTION #####
def coords2state(coords, nbodies=2, mass=1):
    timesteps = coords.shape[0]
    state = coords.T
    state = state.reshape(-1, nbodies, timesteps).transpose(1,0,2)
    mass_vec = mass * np.ones((nbodies, 1, timesteps))
    state = np.concatenate([mass_vec, state], axis=1)
    return state


##### INTEGRATE AN ORBIT OR TWO #####
def sample_orbits(timesteps=4001, trials=1, nbodies=2, orbit_noise=5e-2,
                  min_radius=0.5, max_radius=1.5, t_span=[0, 20], verbose=False, **kwargs):
    
    orbit_settings = locals()
    if verbose:
        print("Making a dataset of near-circular 2-body orbits:")
    
    x, dx, e = [], [], []
    N = timesteps*trials
    while len(x) < N:

        state = random_config(orbit_noise, min_radius, max_radius)
        orbit, settings, t_eval = get_orbit(state, t_points=timesteps, t_span=t_span, **kwargs)
        batch = orbit.transpose(2,0,1).reshape(-1,10)

        for state in batch:
            dstate = update(None, state)
            
            # reshape from [nbodies, state] where state=[m, qx, qy, px, py]
            # m is assumed to be 1
            # to [canonical_coords] = [qx1, qx2, qy1, qy2, px1,px2,....]
            coords = state.reshape(nbodies,5).T[1:].flatten()
            dcoords = dstate.reshape(nbodies,5).T[1:].flatten() #derivatives
            x.append(coords)
            dx.append(dcoords)

            shaped_state = state.copy().reshape(2,5,1)
            e.append(total_energy(shaped_state))

    data = {'coords': np.stack(x)[:N],
            'dcoords': np.stack(dx)[:N],
            'energy': np.stack(e)[:N] }
    return data, orbit_settings


##### MAKE A DATASET #####
def make_orbits_dataset(test_split=0.2, **kwargs):
    data, orbit_settings = sample_orbits(**kwargs)
    
    # make a train/test split
    # split_ix = int(data['coords'].shape[0] * test_split)
    # split_data = {}
    # for k, v in data.items():
    #     split_data[k], split_data['test_' + k] = v[split_ix:], v[:split_ix]
    # data = split_data

    data['meta'] = orbit_settings
    return data


##### LOAD OR SAVE THE DATASET #####
def get_dataset(experiment_name, save_dir, **kwargs):
    '''Returns an orbital dataset. Also constructs
    the dataset if no saved version is available.'''

    path = '{}/{}-orbits-dataset.pkl'.format(save_dir, experiment_name)

    try:
        data = from_pickle(path)
        print("Successfully loaded data from {}".format(path))
    except:
        print("Had a problem loading data from {}. Rebuilding dataset...".format(path))
        data = make_orbits_dataset(**kwargs)
        to_pickle(data, path)

    return data

# %%
# !pwd
# Out:
# /content

# %%
np.random.seed(2)
state = random_config()
orbit, settings = get_orbit(state, t_points=4001, t_span = [0, 20], rtol = 1e-10) # this gives us the data

# %%
for x in settings:
  print(x)
#for y in orbit:
 # print(y)
print(len(orbit))
print(len(orbit[0]))
print(len(orbit[0][0]))
# Out:
# state
# update_fn
# t_points
# t_span
# kwargs
# t_eval
# 2
# 5
# 4001

# %%
'''
Set up training values 

'''

n_train = 4000      # number of training points
n_samples = n_train
x_train = np.zeros([2,5,n_train])
x_train[:,0,:] = settings['t_eval'][:n_train]
x_train[:,1:5,:] = orbit[:,1:,:n_train]
y_train = orbit[:,1:,1:n_train+1]
x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
# x_val, y_val = x_train[:,:,100:1000], y_train[:,:,100:1000]
# x_test, y_test = x_train[:,:,100:3000], y_train[:,:,100:3000]

#print(x_train.shape) #[2, 5, 4000]
#print(y_train.shape) #[2, 4, 4000]

# shuffle and split data
# idx = torch.randperm(n_train + n_val + n_test)
# x_train, y_train = x[idx[:n_train]], y[idx[:n_train]]
# x_val, y_val = x[idx[n_train:n_train + n_val]], y[idx[n_train:n_train + n_val]]
# x_test, y_test = x[idx[n_train + n_val:]], y[idx[n_train + n_val:]]

stepSize = 20/4000
print("stepsize=", stepSize)
# Out:
# stepsize= 0.005

# %%
'''
Create our Network:
  - our width and depth, as well as the function we use to create our ResNet

'''

width = 20
depth = 3
f = net.NN(lay.singleLayer(10, width, act=act.tanhActivation()),
           net.resnetNN(width, depth, h=0.5, act=act.tanhActivation()),
           lay.singleLayer(width, 1, act=act.identityActivation()))

# Pytorch optimizer for the network weights
optimizer = torch.optim.Adam(f.parameters(), lr=1e-3) 
#weight decay is for regularization weight_decay=1e-5 add this for regularization

# %% [markdown]
# ### Transform x_train to nex-by-10 and y_train to nex-by-8

# %%
#Transform x_train to nex-by-10 and y_train to nex-by-8

x_train = torch.cat((x_train[0,:,:],x_train[1,:,:]),axis=0).t()
y_train = torch.cat((y_train[0,:,:],y_train[1,:,:]),axis=0).t()
x_val, y_val = x_train[100:1000,:], y_train[100:1000,:]
x_test, y_test = x_train[100:3000,:], y_train[100:3000,:]

# %%
print(x_train.size()) #[4000, 10]
print(x_val.size()) #[900, 10]
print(x_test.size()) #[2900, 10]
# Out:
# torch.Size([4000, 10])
# torch.Size([900, 10])
# torch.Size([2900, 10])

# %%
#Neural Net on our Training data (f is our function to make the net)
f_train = f(x_train,do_gradient=True,do_hessian = False) 
f_train[1].shape
# Out:
# torch.Size([4000, 10, 1])

# %%
# Test Time stepping 
# Check this for RK4 
y1 = stepSize*f_train[1][:,3:5,0]  + x_train[:,1:3] 
z1 = -1 * stepSize*f_train[1][:,1:3,0] + x_train[:,3:5] 
y2 = stepSize*f_train[1][:,8:10,0]  + x_train[:,6:8] 
z2 = -1 * stepSize*f_train[1][:,6:8,0] + x_train[:,8:10]
y12z12 = torch.cat((y1,z1,y2,z2),dim=1)

# %%
#Our Mean Squared Error Loss Function
def mse_loss(y_true: torch.Tensor,y: torch.Tensor):
  # return (0.5 / y.shape[0]) * torch.norm(y_true - y.view_as(y_true)) ** 2
  return 0.5*torch.mean(torch.sum((y_true - y.view_as(y_true))** 2, dim = 1, keepdim=True))

# %%
#A function for printing the various headers necessary for seeing our network running
def print_headers( verbose: bool = True):
    r"""
    Print headers for nice training
    """
    loss_printouts = ('loss',)
    n_loss = len(loss_printouts)

    headers = (('', '', '|', 'running',) + (n_loss - 1) * ('',) + ('|', 'train',)
               + (n_loss - 1) * ('',) + ('|', 'valid',) + (n_loss - 1) * ('',))

    printouts = ('epoch', 'time') + 3 * (('|',) + loss_printouts)
    printouts_frmt = '{:<15d}{:<15.4f}' + 3 * ('{:<2s}' + n_loss * '{:<15.4e}')

    if verbose:
        print(('{:<15s}{:<15s}' + 3 * ('{:<2s}' + n_loss * '{:<15s}')).format(*headers))
        print(('{:<15s}{:<15s}' + 3 * ('{:<2s}' + n_loss * '{:<15s}')).format(*printouts))

    return headers, printouts, printouts_frmt

# %%
def stepRK4(f, x):
  z = x.clone()
  f_batch= f(z,do_gradient=True,do_hessian = False) #gradient and vals for this batch

  k1y1= f_batch[1][:,1:3,0]
  k1y2= f_batch[1][:,6:8,0]
  k1z1= -f_batch[1][:,3:5,0]
  k1z2= -f_batch[1][:,8:10,0]
  xb1 = z + stepSize/2*torch.cat((torch.ones_like(z[:,0:1]), k1y1, k1z1,
                                    torch.ones_like(z[:,5:6]), k1y2, k1z2), dim=1)
  
  fb1 = f(xb1,do_gradient=True,do_hessian = False)
  k2y1= fb1[1][:,1:3,0]
  k2y2= fb1[1][:,6:8,0]
  k2z1= -fb1[1][:,3:5,0]
  k2z2= -fb1[1][:,8:10,0]
  xb2 = z + stepSize/2*torch.cat((torch.ones_like(z[:,0:1]), k2y1, k2z1,
                                    torch.ones_like(z[:,5:6]), k2y2, k2z2), dim=1)
  
  fb2 = f(xb2,do_gradient=True,do_hessian = False)
  k3y1= fb2[1][:,1:3,0]
  k3y2= fb2[1][:,6:8,0]
  k3z1= -fb2[1][:,3:5,0]
  k3z2= -fb2[1][:,8:10,0]
  xb3 = z + stepSize*torch.cat((torch.ones_like(z[:,0:1]), k3y1, k3z1,
                                    torch.ones_like(z[:,5:6]), k3y2, k3z2), dim=1)
  
  fb3 = f(xb3,do_gradient=True,do_hessian = False)
  k4y1= fb3[1][:,1:3,0]
  k4y2= fb3[1][:,6:8,0]
  k4z1= -fb3[1][:,3:5,0]
  k4z2= -fb3[1][:,8:10,0]

  y1 = stepSize/6*(k1z1+2*k2z1+2*k3z1+k4z1)  + z[:,1:3] 
  z1 = stepSize/6*(k1y1+2*k2y1+2*k3y1+k4y1)  + z[:,3:5] 
  y2 = stepSize/6*(k1z2+2*k2z2+2*k3z2+k4z2)   + z[:,6:8] 
  z2 = stepSize/6*(k1y2+2*k2y2+2*k3y2+k4y2)  + z[:,8:10]

  return torch.cat((y1,z1,y2,z2),dim=1)

# %%
'''
Training our Network RK4
  - Print the table detailing various losses over epochs, and produce a figure 
    showing the training loss as the epochs go on.

'''

# training parameters
max_epochs = 500
batch_size = 500

# get printouts
headers, printouts_str, printouts_frmt = print_headers()

# ---------------------------------------------------------------------------- #
# initial evaluation -> initial training values and gradient
f_train = f(x_train,do_gradient=True,do_hessian = False) 
#now construct the neural nets for validation

#For printing: 
his_iter = (-1, 0.0) + ('|',) + (0,) + ('|',) + (0,) + ('|',) + (0,)
# print(printouts_frmt.format(*his_iter))

# store history
his = np.array([x for x in his_iter if not (x == '|')]).reshape(1, -1)


# ---------------------------------------------------------------------------- #
# main iteration of training 

log_interval = 5 # how often printouts appear
totaltime = 0

for epoch in range(max_epochs): #go through each epoch
    t0 = time.perf_counter()
    # training here
    f.train()
    n = x_train.shape[0] #number of inputs
    b = batch_size
    n_batch = n // b #inputs per batch
    loss = torch.zeros(1) #initializing loss
    running_loss = 0.0

    # shuffle
    idx = torch.randperm(n) #identity

    for i in range(n_batch): #loop through batches
        idxb = idx[i * b:(i + 1) * b] #random permute based on batch number
        xb, yb = x_train[idxb], y_train[idxb] #get that batch data
        optimizer.zero_grad()
        ystep = stepRK4(f, xb)
        # f_batch= f(xb,do_gradient=True,do_hessian = False) #gradient and vals for this batch

        # k1y1= f_batch[1][:,1:3,0]
        # k1y2= f_batch[1][:,6:8,0]
        # k1z1= -f_batch[1][:,3:5,0]
        # k1z2= -f_batch[1][:,8:10,0]
        # xb1 = xb + stepSize/2*torch.cat((torch.ones_like(xb[:,0:1]), k1y1, k1z1,
        #                                  torch.ones_like(xb[:,5:6]), k1y2, k1z2), dim=1)
        
        # fb1 = f(xb1,do_gradient=True,do_hessian = False)
        # k2y1= fb1[1][:,1:3,0]
        # k2y2= fb1[1][:,6:8,0]
        # k2z1= -fb1[1][:,3:5,0]
        # k2z2= -fb1[1][:,8:10,0]
        # xb2 = xb + stepSize/2*torch.cat((torch.ones_like(xb[:,0:1]), k2y1, k2z1,
        #                                  torch.ones_like(xb[:,5:6]), k2y2, k2z2), dim=1)
        
        # fb2 = f(xb2,do_gradient=True,do_hessian = False)
        # k3y1= fb2[1][:,1:3,0]
        # k3y2= fb2[1][:,6:8,0]
        # k3z1= -fb2[1][:,3:5,0]
        # k3z2= -fb2[1][:,8:10,0]
        # xb3 = xb + stepSize*torch.cat((torch.ones_like(xb[:,0:1]), k3y1, k3z1,
        #                                  torch.ones_like(xb[:,5:6]), k3y2, k3z2), dim=1)
        
        # fb3 = f(xb3,do_gradient=True,do_hessian = False)
        # k4y1= fb3[1][:,1:3,0]
        # k4y2= fb3[1][:,6:8,0]
        # k4z1= -fb3[1][:,3:5,0]
        # k4z2= -fb3[1][:,8:10,0]

        # y1 = stepSize/6*(k1z1+2*k2z1+2*k3z1+k4z1)  + xb[:,1:3] 
        # z1 = stepSize/6*(k1y1+2*k2y1+2*k3y1+k4y1)  + xb[:,3:5] 
        # y2 = stepSize/6*(k1z2+2*k2z2+2*k3z2+k4z2)   + xb[:,6:8] 
        # z2 = stepSize/6*(k1y2+2*k2y2+2*k3y2+k4y2)  + xb[:,8:10]




        '''
        incorrect RK4 scheme
        #time steps (like we saw earlier)
        k1y1= stepSize / 6 * f_batch[1][:,1:3,0]
        k2y1= stepSize / 3 * f_batch[1][:,1:3,0]+stepSize*k1y1/2
        k3y1= stepSize / 3 * f_batch[1][:,1:3,0]+stepSize*k2y1/2
        k4y1= stepSize / 6 * f_batch[1][:,1:3,0]+stepSize*k3y1

        k1y2= stepSize / 6 *f_batch[1][:,6:8,0]
        k2y2= stepSize / 3 * f_batch[1][:,6:8,0]+stepSize*k1y2/2
        k3y2= stepSize / 3 * f_batch[1][:,6:8,0]+stepSize*k2y2/2
        k4y2= stepSize / 6 * f_batch[1][:,6:8,0]+stepSize*k3y2

        k1z1= stepSize / 6 * f_batch[1][:,3:5,0]
        k2z1= stepSize / 3 * f_batch[1][:,3:5,0]+ stepSize*k1z1/2
        k3z1= stepSize / 3 * f_batch[1][:,3:5,0]+stepSize*k2z1/2
        k4z1= stepSize / 6 * f_batch[1][:,3:5,0]+stepSize*k3z1

        k1z2= stepSize / 6 * f_batch[1][:,8:10,0]
        k2z2= stepSize / 3 * f_batch[1][:,8:10,0]+stepSize*k1z2/2
        k3z2= stepSize / 3 * f_batch[1][:,8:10,0]+stepSize*k2z2/2
        k4z2= stepSize / 6 * f_batch[1][:,8:10,0]+stepSize*k3z2



        y1 = stepSize*(k1z1+k2z1+k3z1+k4z1)  + xb[:,1:3] 
        z1 = -1 *stepSize*(k1y1+k2y1+k3y1+k4y1)  + xb[:,3:5] 
        y2 = stepSize*(k1z2+k2z2+k3z2+k4z2)   + xb[:,6:8] 
        z2 = -1 * stepSize*(k1y2+k2y2+k3y2+k4y2)  + xb[:,8:10]
        '''
        # torch.cat((y1,z1,y2,z2),dim=1).shape
        loss = mse_loss(ystep,yb) 
        running_loss += b * loss.item()

        # update network weights
        loss.backward(retain_graph=True) #back propagation 
        optimizer.step() #step so we can then do the next batch

    running_loss = (running_loss / n,) #averge it 
    
    t1 = time.perf_counter()

    # test
    # fc_train= f(x_train,do_gradient=True,do_hessian = False)

    # k1y1= stepSize / 6 * fc_train[1][:,1:3,0]
    # k2y1= stepSize / 3 * fc_train[1][:,1:3,0]+stepSize*k1y1/2
    # k3y1= stepSize / 3 * fc_train[1][:,1:3,0]+stepSize*k2y1/2
    # k4y1= stepSize / 6 * fc_train[1][:,1:3,0]+stepSize*k3y1

    # k1y2= stepSize / 6 *fc_train[1][:,6:8,0]
    # k2y2= stepSize / 3 * fc_train[1][:,6:8,0]+stepSize*k1y2/2
    # k3y2= stepSize / 3 * fc_train[1][:,6:8,0]+stepSize*k2y2/2
    # k4y2= stepSize / 6 * fc_train[1][:,6:8,0]+stepSize*k3y2

    # k1z1= stepSize / 6 * fc_train[1][:,3:5,0]
    # k2z1= stepSize / 3 * fc_train[1][:,3:5,0]+ stepSize*k1z1/2
    # k3z1= stepSize / 3 * fc_train[1][:,3:5,0]+stepSize*k2z1/2
    # k4z1= stepSize / 6 * fc_train[1][:,3:5,0]+stepSize*k3z1

    # k1z2= stepSize / 6 * fc_train[1][:,8:10,0]
    # k2z2= stepSize / 3 * fc_train[1][:,8:10,0]+stepSize*k1z2/2
    # k3z2= stepSize / 3 * fc_train[1][:,8:10,0]+stepSize*k2z2/2
    # k4z2= stepSize / 6 * fc_train[1][:,8:10,0]+stepSize*k3z2

    # y1 = stepSize*(k1z1+k2z1+k3z1+k4z1)  + x_train[:,1:3] 
    # z1 = -1 *stepSize*(k1y1+k2y1+k3y1+k4y1)  + x_train[:,3:5] 
    # y2 = stepSize*(k1z2+k2z2+k3z2+k4z2)   + x_train[:,6:8] 
    # z2 = -1 * stepSize*(k1y2+k2y2+k3y2+k4y2)  + x_train[:,8:10]


    ytrain = stepRK4(f, x_train)
    loss_train = mse_loss(ytrain,y_train)

    #validation
    # fc_val= f(x_val,do_gradient=True,do_hessian = False)

    # k1y1= stepSize / 6 * fc_val[1][:,1:3,0]
    # k2y1= stepSize / 3 * fc_val[1][:,1:3,0]+stepSize*k1y1/2
    # k3y1= stepSize / 3 * fc_val[1][:,1:3,0]+stepSize*k2y1/2
    # k4y1= stepSize / 6 * fc_val[1][:,1:3,0]+stepSize*k3y1

    # k1y2= stepSize / 6 *fc_val[1][:,6:8,0]
    # k2y2= stepSize / 3 * fc_val[1][:,6:8,0]+stepSize*k1y2/2
    # k3y2= stepSize / 3 * fc_val[1][:,6:8,0]+stepSize*k2y2/2
    # k4y2= stepSize / 6 * fc_val[1][:,6:8,0]+stepSize*k3y2

    # k1z1= stepSize / 6 * fc_val[1][:,3:5,0]
    # k2z1= stepSize / 3 * fc_val[1][:,3:5,0]+ stepSize*k1z1/2
    # k3z1= stepSize / 3 * fc_val[1][:,3:5,0]+stepSize*k2z1/2
    # k4z1= stepSize / 6 * fc_val[1][:,3:5,0]+stepSize*k3z1

    # k1z2= stepSize / 6 * fc_val[1][:,8:10,0]
    # k2z2= stepSize / 3 * fc_val[1][:,8:10,0]+stepSize*k1z2/2
    # k3z2= stepSize / 3 * fc_val[1][:,8:10,0]+stepSize*k2z2/2
    # k4z2= stepSize / 6 * fc_val[1][:,8:10,0]+stepSize*k3z2


    # y1 = stepSize*(k1z1+k2z1+k3z1+k4z1)  + x_val[:,1:3] 
    # z1 = -1 *stepSize*(k1y1+k2y1+k3y1+k4y1)  + x_val[:,3:5] 
    # y2 = stepSize*(k1z2+k2z2+k3z2+k4z2)   + x_val[:,6:8] 
    # z2 = -1 * stepSize*(k1y2+k2y2+k3y2+k4y2)  + x_val[:,8:10]

    
    yval = stepRK4(f, x_val)
    loss_val = mse_loss(yval,y_val)
    t = t1-t0
    totaltime = totaltime + t
    #for printing:
    his_iter = (epoch, t1 - t0) + ('|',) + running_loss + ('|',) + (loss_train.item(),) + ('|',) + (loss_val.item(),)
    if epoch % log_interval == 0:
      print(printouts_frmt.format(*his_iter))

    # store history
    idx = [idx for idx, n in enumerate(np.array([x for x in printouts_str if not (x == '|')])) if n == 'loss'][1]
    his = np.concatenate((his, np.array([x for x in his_iter if not (x == '|')]).reshape(1, -1)), axis=0)


# ---------------------------------------------------------------------------- #
# overall performance on test data
# f_test= f(x_test,do_gradient=True,do_hessian = False)

# k1y1= stepSize / 6 * f_test[1][:,1:3,0]
# k2y1= stepSize / 3 * f_test[1][:,1:3,0]+stepSize*k1y1/2
# k3y1= stepSize / 3 * f_test[1][:,1:3,0]+stepSize*k2y1/2
# k4y1= stepSize / 6 * f_test[1][:,1:3,0]+stepSize*k3y1

# k1y2= stepSize / 6 *f_test[1][:,6:8,0]
# k2y2= stepSize / 3 * f_test[1][:,6:8,0]+stepSize*k1y2/2
# k3y2= stepSize / 3 * f_test[1][:,6:8,0]+stepSize*k2y2/2
# k4y2= stepSize / 6 * f_test[1][:,6:8,0]+stepSize*k3y2

# k1z1= stepSize / 6 * f_test[1][:,3:5,0]
# k2z1= stepSize / 3 * f_test[1][:,3:5,0]+ stepSize*k1z1/2
# k3z1= stepSize / 3 * f_test[1][:,3:5,0]+stepSize*k2z1/2
# k4z1= stepSize / 6 * f_test[1][:,3:5,0]+stepSize*k3z1

# k1z2= stepSize / 6 * f_test[1][:,8:10,0]
# k2z2= stepSize / 3 * f_test[1][:,8:10,0]+stepSize*k1z2/2
# k3z2= stepSize / 3 * f_test[1][:,8:10,0]+stepSize*k2z2/2
# k4z2= stepSize / 6 * f_test[1][:,8:10,0]+stepSize*k3z2


# y1 = stepSize*(k1z1+k2z1+k3z1+k4z1)  + x_test[:,1:3] 
# z1 = -1 *stepSize*(k1y1+k2y1+k3y1+k4y1)  + x_test[:,3:5] 
# y2 = stepSize*(k1z2+k2z2+k3z2+k4z2)   + x_test[:,6:8] 
# z2 = -1 * stepSize*(k1y2+k2y2+k3y2+k4y2)  + x_test[:,8:10]

ytest = stepRK4(f,x_test)
loss_test = mse_loss(ytest,y_test)
print('Test Loss: %0.4e' % loss_test.item())
print('Time:' + str(totaltime))


# ---------------------------------------------------------------------------- #
#For Convergence Plot:

fs=15; tpad=6; lw=3; ms=30

rc('axes', linewidth=2)
fig = plt.figure()
idx = [idx for idx, n in enumerate(np.array([x for x in printouts_str if not (x == '|')])) if n == 'loss'][1]

plt.semilogy(his[1::, 0], his[1::, idx], linewidth=lw)

plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.title('Training Loss', fontsize=fs) 
ax = gca()
#plt.legend()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.show()
fig.savefig('conv_plotrk4.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) #to save the image
# Out:
#                               | running        | train          | valid
# epoch          time           | loss           | loss           | loss
# 0              0.6975         | 1.5050e-05     | 1.2022e-05     | 1.5688e-05
# 5              0.4717         | 6.8716e-06     | 6.4514e-06     | 4.7861e-06
# 10             0.4758         | 3.2380e-06     | 2.9193e-06     | 2.9172e-06
# 15             0.6389         | 1.1474e-06     | 1.0165e-06     | 1.0142e-06
# 20             0.3485         | 4.5094e-07     | 4.1428e-07     | 3.4392e-07
# 25             0.2851         | 2.5869e-07     | 2.4766e-07     | 1.8439e-07
# 30             0.2796         | 1.8337e-07     | 1.7685e-07     | 1.0886e-07
# 35             0.2781         | 1.3974e-07     | 1.3568e-07     | 7.3525e-08
# 40             0.2810         | 1.1125e-07     | 1.0851e-07     | 5.6975e-08
# 45             0.2814         | 8.9803e-08     | 8.7525e-08     | 4.6115e-08
# 50             0.2789         | 7.1983e-08     | 7.0173e-08     | 3.9400e-08
# 55             0.2760         | 5.7549e-08     | 5.6031e-08     | 3.2316e-08
# 60             0.2822         | 4.6612e-08     | 4.5569e-08     | 2.7339e-08
# 65             0.2831         | 3.8861e-08     | 3.8082e-08     | 2.4095e-08
# 70             0.2775         | 3.3052e-08     | 3.2436e-08     | 2.1073e-08
# 75             0.2814         | 2.8531e-08     | 2.8179e-08     | 1.8672e-08
# 80             0.3114         | 2.4996e-08     | 2.4781e-08     | 1.6565e-08
# 85             0.2945         | 2.2081e-08     | 2.1780e-08     | 1.4848e-08
# 90             0.2913         | 1.9592e-08     | 1.9359e-08     | 1.3750e-08
# 95             0.2835         | 1.7565e-08     | 1.7379e-08     | 1.2324e-08
# 100            0.2740         | 1.5771e-08     | 1.5581e-08     | 1.1343e-08
# 105            0.2789         | 1.4205e-08     | 1.4031e-08     | 1.0270e-08
# 110            0.3983         | 1.2858e-08     | 1.2695e-08     | 9.4251e-09
# 115            0.2818         | 1.1687e-08     | 1.1575e-08     | 8.7364e-09
# 120            0.2804         | 1.0632e-08     | 1.0499e-08     | 8.0771e-09
# 125            0.2768         | 9.7467e-09     | 9.6328e-09     | 7.5714e-09
# 130            0.2748         | 8.9420e-09     | 8.8002e-09     | 6.9706e-09
# 135            0.2850         | 8.1315e-09     | 8.0423e-09     | 6.5054e-09
# 140            0.4131         | 7.4965e-09     | 7.3930e-09     | 5.9509e-09
# 145            0.2751         | 6.8797e-09     | 6.8163e-09     | 5.5526e-09
# 150            0.2751         | 6.3491e-09     | 6.2651e-09     | 5.1812e-09
# 155            0.2721         | 5.8717e-09     | 5.8315e-09     | 4.7688e-09
# 160            0.2766         | 5.4119e-09     | 5.3713e-09     | 4.4775e-09
# 165            0.2854         | 5.0218e-09     | 4.9621e-09     | 4.1228e-09
# 170            0.4192         | 4.6629e-09     | 4.6240e-09     | 3.8610e-09
# 175            0.2909         | 4.3696e-09     | 4.2860e-09     | 3.6201e-09
# 180            0.2736         | 4.0533e-09     | 4.0143e-09     | 3.3370e-09
# 185            0.2867         | 3.7886e-09     | 3.7531e-09     | 3.1707e-09
# 190            0.2849         | 3.5236e-09     | 3.5186e-09     | 2.9740e-09
# 195            0.2802         | 3.3285e-09     | 3.3018e-09     | 2.8157e-09
# 200            0.4254         | 3.1063e-09     | 3.0869e-09     | 2.5552e-09
# 205            0.2915         | 2.9305e-09     | 2.9007e-09     | 2.4355e-09
# 210            0.2881         | 2.7517e-09     | 2.7322e-09     | 2.2617e-09
# 215            0.2941         | 2.6302e-09     | 2.5943e-09     | 2.1598e-09
# 220            0.2794         | 2.4594e-09     | 2.4361e-09     | 2.0165e-09
# 225            0.2808         | 2.3286e-09     | 2.3265e-09     | 1.8849e-09
# 230            0.4096         | 2.2271e-09     | 2.2074e-09     | 1.8028e-09
# 235            0.2779         | 2.1049e-09     | 2.0968e-09     | 1.6943e-09
# 240            0.2768         | 1.9843e-09     | 1.9696e-09     | 1.5682e-09
# 245            0.2791         | 1.8993e-09     | 1.8661e-09     | 1.4974e-09
# 250            0.2768         | 1.8021e-09     | 1.7870e-09     | 1.4361e-09
# 255            0.2887         | 1.7236e-09     | 1.7078e-09     | 1.3791e-09
# 260            0.4081         | 1.6637e-09     | 1.6632e-09     | 1.2971e-09
# 265            0.2878         | 1.5880e-09     | 1.5437e-09     | 1.2135e-09
# 270            0.2847         | 1.5021e-09     | 1.5087e-09     | 1.2107e-09
# 275            0.2732         | 1.4390e-09     | 1.4181e-09     | 1.0803e-09
# 280            0.2874         | 1.3758e-09     | 1.3611e-09     | 1.0388e-09
# 285            0.2803         | 1.3288e-09     | 1.2958e-09     | 1.0101e-09
# 290            0.3157         | 1.2710e-09     | 1.3135e-09     | 9.6039e-10
# 295            0.2841         | 1.2577e-09     | 1.2104e-09     | 9.2601e-10
# 300            0.2745         | 1.1605e-09     | 1.1483e-09     | 8.7358e-10
# 305            0.2785         | 1.1494e-09     | 1.1307e-09     | 8.2597e-10
# 310            0.2942         | 1.0673e-09     | 1.0588e-09     | 7.8421e-10
# 315            0.2797         | 1.0488e-09     | 1.0504e-09     | 7.6134e-10
# 320            0.2904         | 9.9787e-10     | 9.9801e-10     | 7.2196e-10
# 325            0.2853         | 9.5567e-10     | 9.5524e-10     | 7.1501e-10
# 330            0.2842         | 9.2248e-10     | 9.3522e-10     | 6.6465e-10
# 335            0.2819         | 9.0699e-10     | 9.0054e-10     | 6.3153e-10
# 340            0.2815         | 8.7800e-10     | 8.5435e-10     | 6.2453e-10
# 345            0.2856         | 8.4058e-10     | 8.3032e-10     | 5.9625e-10
# 350            0.2850         | 8.0801e-10     | 7.9952e-10     | 5.7510e-10
# 355            0.2809         | 7.8735e-10     | 7.8727e-10     | 5.6712e-10
# 360            0.2816         | 7.6715e-10     | 7.5389e-10     | 5.4504e-10
# 365            0.2723         | 7.4420e-10     | 7.5513e-10     | 5.1149e-10
# 370            0.2767         | 7.3750e-10     | 7.4407e-10     | 5.2139e-10
# 375            0.3214         | 7.0543e-10     | 6.9404e-10     | 4.7066e-10
# 380            0.3002         | 6.7973e-10     | 6.7466e-10     | 4.5895e-10
# 385            0.2912         | 6.7892e-10     | 6.5726e-10     | 4.4340e-10
# 390            0.3037         | 6.5955e-10     | 6.8606e-10     | 4.4153e-10
# 395            0.2726         | 6.2596e-10     | 6.1988e-10     | 4.0789e-10
# 400            0.2685         | 6.1468e-10     | 5.9834e-10     | 4.0056e-10
# 405            0.4128         | 5.9254e-10     | 6.0733e-10     | 3.9674e-10
# 410            0.2816         | 6.1120e-10     | 5.7327e-10     | 3.7854e-10
# 415            0.2825         | 5.6697e-10     | 5.7450e-10     | 3.6737e-10
# 420            0.2766         | 5.5711e-10     | 5.5077e-10     | 3.6743e-10
# 425            0.2722         | 5.3709e-10     | 5.3780e-10     | 3.5185e-10
# 430            0.2733         | 5.6795e-10     | 5.6899e-10     | 3.3237e-10
# 435            0.4166         | 5.2853e-10     | 5.1151e-10     | 3.2657e-10
# 440            0.2769         | 5.2714e-10     | 4.9751e-10     | 3.1763e-10
# 445            0.2806         | 4.9066e-10     | 5.4537e-10     | 3.1541e-10
# 450            0.2741         | 5.1535e-10     | 4.7683e-10     | 3.0039e-10
# 455            0.2920         | 5.0649e-10     | 4.6879e-10     | 2.9350e-10
# 460            0.2932         | 4.6421e-10     | 4.6934e-10     | 2.9395e-10
# 465            0.4156         | 4.9008e-10     | 4.8739e-10     | 3.0035e-10
# 470            0.2950         | 4.8083e-10     | 5.3904e-10     | 3.1799e-10
# 475            0.2865         | 4.5893e-10     | 4.5463e-10     | 2.6641e-10
# 480            0.2830         | 4.5846e-10     | 4.4876e-10     | 2.7621e-10
# 485            0.2843         | 4.3882e-10     | 4.2316e-10     | 2.5051e-10
# 490            0.2830         | 4.5582e-10     | 4.3970e-10     | 2.7692e-10
# 495            0.4145         | 4.1537e-10     | 4.3438e-10     | 2.5024e-10
# Test Loss: 3.7785e-10
# Time:156.83208183100038

# %%
# Go back and solve the ODE, put info in sol array

xinit = x_train[0:1,:]
steps = 4001
h = stepSize
sol = torch.zeros(steps,8) #initialize
t_solspan = np.zeros(steps) #initialize
t=0

for i in range(steps): #for each step
  # fb = f(xinit,do_gradient=True,do_hessian = False) #plug x_init

  # y1 = stepSize*fb[1][:,3:5,0]  + xinit[:,1:3] 
  # z1 = -1 * stepSize*fb[1][:,1:3,0] + xinit[:,3:5] 
  # y2 = stepSize*fb[1][:,8:10,0]  + xinit[:,6:8] 
  # z2 = -1 * stepSize*fb[1][:,6:8,0] + xinit[:,8:10]
  yinit = stepRK4(f, xinit)
  # print(yinit.shape)
  t = t + h
  t_solspan[i] = t
  xinit = torch.cat((xinit[0:1,0:1] + h, yinit[0:1,0:4], xinit[0:1,5:6] + h, yinit[0:1,4:8]),dim=1)
  sol[i:i+1,:] = yinit #store in solutions
# t_solspan[1] = t

# %%
sol = sol.t().detach().numpy()

# %%
orbit_sol = np.ones((2,5,steps))
orbit_sol[0,1:5,:] = sol[:4,:]
orbit_sol[1,1:5,:] = sol[4:8,:]

# %%
orbit_sol.shape
# Out:
# (2, 5, 4001)

# %%
#Here we are plotting our learned positions against the true positions

fs=15; tpad=6; lw=3; ms=30

plt.title('RK4 Learned Position Values', fontsize=fs)

#lines
plt.plot(t_solspan,orbit_sol[0][1,:], "k-",linewidth=lw,  color = "orange", label='Learned Body 1 Position'.format(i))
plt.plot(t_solspan,orbit_sol[1][1,:], "k-", linewidth=lw, color = "royalblue", label='Learned Body 2 Position'.format(i))

holder = 0

plt.plot(settings['t_eval'][:steps],orbit[0][1,:steps], "k-.", label='True Values')
plt.plot(settings['t_eval'][:steps],orbit[1][1,:steps], "k-.")

#labels
plt.xlabel('Time', fontsize=12) 
plt.ylabel('px', fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':10})

ax = gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('RK4 learned position.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-22-4226879987a7>:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(t_solspan,orbit_sol[0][1,:], "k-",linewidth=lw,  color = "orange", label='Learned Body 1 Position'.format(i))
# <ipython-input-22-4226879987a7>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(t_solspan,orbit_sol[1][1,:], "k-", linewidth=lw, color = "royalblue", label='Learned Body 2 Position'.format(i))

# %%
#Plot the predicted Trajectories of our bodies
fs=15; tpad=6; lw=3; ms=30
rc('axes', linewidth=2)

plt.title('RK4 Trajectories', fontsize=fs, pad=tpad)
colors = ["orange", "royalblue"]
labels = ["Body 1", "Body 2"]
plt.xlabel('px', fontsize=12) 
plt.ylabel('qx', fontsize=12)


ax = gca()

for i, path in enumerate(orbit_sol):
    plt.plot(path[1], path[2], "k-", linewidth=lw, color = colors[i], label=labels[i].format(i))
for i, path in enumerate(orbit):
    plt.plot(path[1], path[2], "k:", linewidth=lw, label='ground truth'.format(i))
plt.legend(fontsize=7, loc='lower right', prop={'size':10})

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('RK4 Trajectories.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-23-38706b3be164>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(path[1], path[2], "k-", linewidth=lw, color = colors[i], label=labels[i].format(i))

# %%
total_energy(orbit)
# Out:
# array([-0.27994036, -0.27994036, -0.27994036, ..., -0.27995311,
#        -0.27995311, -0.27995311])

# %%
#Plot the energy values


tail=10000; pfrac=0.05


k = 4001


tstart = max(0, k-tail)

real_pe = potential_energy(orbit_sol[...,tstart:k])
real_ke = kinetic_energy(orbit_sol[...,tstart:k])
real_etot = total_energy(orbit_sol[...,tstart:k])
ymin = np.min([real_pe.min(), real_ke.min(), real_etot.min()])
ymax = np.max([real_pe.max(), real_ke.max(), real_etot.max()])
pad = (ymax-ymin)*pfrac
ymin -= pad
ymax += pad
rc('axes', linewidth=2)

#lines
plt.plot(settings['t_eval'], potential_energy(orbit), 'k--',linewidth=lw,label='potential')
plt.plot(settings['t_eval'], kinetic_energy(orbit),'k:',linewidth=lw, label='kinetic')
plt.plot(settings['t_eval'], total_energy(orbit),  'k-.',linewidth=lw,label='total')
plt.plot(settings['t_eval'], real_ke,  label='Kinetic',color = 'blue')
plt.plot(settings['t_eval'], real_pe, label='Potential',color = "purple")
plt.plot(settings['t_eval'], real_etot,  label='Total',color = "red")

ax = gca()

#labels
plt.title('RK4 Energy', fontsize=fs, pad=tpad)
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Energy", fontsize=12)
plt.ylim(ymin, ymax)
plt.legend(fontsize=7, loc='best', prop={'size':10})

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('RK4 Energy.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)

# %%
plt.figure()
plt.title('RK4 Position Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'][:steps],(orbit[0][1,:steps]-orbit_sol[0][1,:])/orbit[0][1,:steps],linewidth=lw,label='Learned Body 1 Error'.format(i))
plt.plot(settings['t_eval'][:steps],(orbit[1][1,:steps]-orbit_sol[1][1,:])/orbit[1][1,:steps],linewidth=lw,label='Learned Body 2 Error'.format(i))
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyRK4ErrorPosition.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) 


pathOneOrbitSol = []
pathTwoOrbitSol = []
pathOneOrbit = []
pathTwoOrbit = []

for i, path in enumerate(orbit_sol):
    pathOneOrbitSol.append(path[1])
    pathTwoOrbitSol.append(path[2])
for i, path in enumerate(orbit):
    pathOneOrbit.append(path[1])
    pathTwoOrbit.append(path[2])

pathOneOrbitSol = np.array(pathOneOrbitSol)
pathTwoOrbitSol = np.array(pathTwoOrbitSol)
pathOneOrbit = np.array(pathOneOrbit)
pathTwoOrbit = np.array(pathTwoOrbit)

plt.figure()
plt.title('RK4 Trajectories Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'],np.abs(pathOneOrbitSol-pathOneOrbit)[0]/np.abs(pathOneOrbitSol)[0]+np.abs(pathOneOrbitSol-pathOneOrbit)[1]/np.abs(pathOneOrbitSol[1]),linewidth=lw,label='Trajectories Body 1 Error'.format(i))
plt.plot(settings['t_eval'],np.abs(pathTwoOrbitSol-pathTwoOrbit)[0]/np.abs(pathTwoOrbitSol)[0]+np.abs(pathTwoOrbitSol-pathTwoOrbit)[1]/np.abs(pathTwoOrbitSol)[1],linewidth=lw,label='Trajectories Body 2 Error'.format(i))
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyRK4ErrorTrajectories.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) 

plt.figure()
plt.title('RK4 Energy Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'], (real_ke-kinetic_energy(orbit))/kinetic_energy(orbit),'k--', linewidth=lw, label='Kinetic Error', color = 'blue')
plt.plot(settings['t_eval'], (real_pe-potential_energy(orbit))/potential_energy(orbit),'k:', linewidth=lw, label='Potential Error' ,color = 'purple')
plt.plot(settings['t_eval'], (real_etot-total_energy(orbit))/total_energy(orbit),'k-.', linewidth=lw, label='Total Error',color = "red")
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.ylim(ymin, ymax)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyRK4ErrorEnergy.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-26-a176d4c36519>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_ke-kinetic_energy(orbit))/kinetic_energy(orbit),'k--', linewidth=lw, label='Kinetic Error', color = 'blue')
# <ipython-input-26-a176d4c36519>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k:" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_pe-potential_energy(orbit))/potential_energy(orbit),'k:', linewidth=lw, label='Potential Error' ,color = 'purple')
# <ipython-input-26-a176d4c36519>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_etot-total_energy(orbit))/total_energy(orbit),'k-.', linewidth=lw, label='Total Error',color = "red")

# %%
'''
Set up training values 

'''



n_train = 4000      # number of training points
n_samples = n_train
x_train = np.zeros([2,5,n_train])
x_train[:,0,:] = settings['t_eval'][:n_train]
x_train[:,1:5,:] = orbit[:,1:,:n_train]
y_train = orbit[:,1:,1:n_train+1]
x_train, y_train = torch.tensor(x_train), torch.tensor(y_train)
# x_val, y_val = x_train[:,:,100:1000], y_train[:,:,100:1000]
# x_test, y_test = x_train[:,:,100:3000], y_train[:,:,100:3000]

#print(x_train.shape) #[2, 5, 4000]
#print(y_train.shape) #[2, 4, 4000]

# shuffle and split data
# idx = torch.randperm(n_train + n_val + n_test)
# x_train, y_train = x[idx[:n_train]], y[idx[:n_train]]
# x_val, y_val = x[idx[n_train:n_train + n_val]], y[idx[n_train:n_train + n_val]]
# x_test, y_test = x[idx[n_train + n_val:]], y[idx[n_train + n_val:]]

stepSize = 20/4000
print("stepsize=", stepSize)
# Out:
# stepsize= 0.005

# %%
width = 20
depth = 3
f = net.NN(lay.singleLayer(10, width, act=act.tanhActivation()),
           net.resnetNN(width, depth, h=0.5, act=act.tanhActivation()),
           lay.singleLayer(width, 1, act=act.identityActivation()))

# Pytorch optimizer for the network weights
optimizer = torch.optim.Adam(f.parameters(), lr=1e-3) 
#weight decay is for regularization weight_decay=1e-5 add this for regularization

# %%
#Transform x_train to nex-by-10 and y_train to nex-by-8

x_train = torch.cat((x_train[0,:,:],x_train[1,:,:]),axis=0).t()
y_train = torch.cat((y_train[0,:,:],y_train[1,:,:]),axis=0).t()
x_val, y_val = x_train[100:1000,:], y_train[100:1000,:]
x_test, y_test = x_train[100:3000,:], y_train[100:3000,:]
print(x_train.size()) #[4000, 10]
print(x_val.size()) #[900, 10]
print(x_test.size()) #[2900, 10]
# Out:
# torch.Size([4000, 10])
# torch.Size([900, 10])
# torch.Size([2900, 10])

# %%
'''
Training our Network
  - Print the table detailing various losses over epochs, and produce a figure 
    showing the training loss as the epochs go on.

'''

# training parameters
max_epochs = 500
batch_size = 500

# get printouts
headers, printouts_str, printouts_frmt = print_headers()

# ---------------------------------------------------------------------------- #
# initial evaluation -> initial training values and gradient
f_train = f(x_train,do_gradient=True,do_hessian = False) 
#now construct the neural nets for validation

#For printing: 
his_iter = (-1, 0.0) + ('|',) + (0,) + ('|',) + (0,) + ('|',) + (0,)
# print(printouts_frmt.format(*his_iter))

# store history
his = np.array([x for x in his_iter if not (x == '|')]).reshape(1, -1)


# ---------------------------------------------------------------------------- #
# main iteration of training 

log_interval = 5 # how often printouts 
totaltime = 0

for epoch in range(max_epochs): #go through each epoch
    t0 = time.perf_counter()
    # training here
    f.train()
    n = x_train.shape[0] #number of inputs
    b = batch_size
    n_batch = n // b #inputs per batch
    loss = torch.zeros(1) #initializing loss
    running_loss = 0.0

    # shuffle
    idx = torch.randperm(n) #identity

    for i in range(n_batch): #loop through batches
        idxb = idx[i * b:(i + 1) * b] #random permute based on batch number
        xb, yb = x_train[idxb], y_train[idxb] #get that batch data
        optimizer.zero_grad()
        f_batch= f(xb,do_gradient=True,do_hessian = False) #gradient and vals for this batch

        #time steps (like we saw earlier)
        y1 = stepSize*f_batch[1][:,3:5,0]  + xb[:,1:3] 
        z1 = -1 * stepSize*f_batch[1][:,1:3,0] + xb[:,3:5] 
        y2 = stepSize*f_batch[1][:,8:10,0]  + xb[:,6:8] 
        z2 = -1 * stepSize*f_batch[1][:,6:8,0] + xb[:,8:10]
        # torch.cat((y1,z1,y2,z2),dim=1).shape
        loss = mse_loss(torch.cat((y1,z1,y2,z2),dim=1),yb) 
        running_loss += b * loss.item()

        # update network weights
        loss.backward(retain_graph=True) #back propagation 
        optimizer.step() #step so we can then do the next batch

    running_loss = (running_loss / n,) #averge it 
    
    t1 = time.perf_counter()

    # test
    fc_train= f(x_train,do_gradient=True,do_hessian = False)

    y1 = stepSize*fc_train[1][:,3:5,0]  + x_train[:,1:3] 
    z1 = -1 * stepSize*fc_train[1][:,1:3,0] + x_train[:,3:5] 
    y2 = stepSize*fc_train[1][:,8:10,0]  + x_train[:,6:8] 
    z2 = -1 * stepSize*fc_train[1][:,6:8,0] + x_train[:,8:10]
    
    loss_train = mse_loss(torch.cat((y1,z1,y2,z2),dim=1),y_train)

    #validation
    fc_val= f(x_val,do_gradient=True,do_hessian = False)
    
    y1 = stepSize*fc_val[1][:,3:5,0]  + x_val[:,1:3] 
    z1 = -1 * stepSize*fc_val[1][:,1:3,0] + x_val[:,3:5] 
    y2 = stepSize*fc_val[1][:,8:10,0]  + x_val[:,6:8] 
    z2 = -1 * stepSize*fc_val[1][:,6:8,0] + x_val[:,8:10]
    
    loss_val = mse_loss(torch.cat((y1,z1,y2,z2),dim=1),y_val)
    t = t1-t0
    totaltime = totaltime + t

    #for printing:
    his_iter = (epoch, t1 - t0) + ('|',) + running_loss + ('|',) + (loss_train.item(),) + ('|',) + (loss_val.item(),)
    if epoch % log_interval == 0:
      print(printouts_frmt.format(*his_iter))

    # store history
    idx = [idx for idx, n in enumerate(np.array([x for x in printouts_str if not (x == '|')])) if n == 'loss'][1]
    his = np.concatenate((his, np.array([x for x in his_iter if not (x == '|')]).reshape(1, -1)), axis=0)


# ---------------------------------------------------------------------------- #
# overall performance on test data
f_test= f(x_test,do_gradient=True,do_hessian = False)
y1 = stepSize*f_test[1][:,3:5,0]  + x_test[:,1:3] 
z1 = -1 * stepSize*f_test[1][:,1:3,0] + x_test[:,3:5] 
y2 = stepSize*f_test[1][:,8:10,0]  + x_test[:,6:8] 
z2 = -1 * stepSize*f_test[1][:,6:8,0] + x_test[:,8:10]

loss_test = mse_loss(torch.cat((y1,z1,y2,z2),dim=1),y_test)
print('Test Loss: %0.4e' % loss.item())
print('Time:' + str(totaltime))


# ---------------------------------------------------------------------------- #
#For Convergence Plot:

fs=15; tpad=6; lw=3; ms=30

rc('axes', linewidth=2)
fig = plt.figure()
idx = [idx for idx, n in enumerate(np.array([x for x in printouts_str if not (x == '|')])) if n == 'loss'][1]

plt.semilogy(his[1::, 0], his[1::, idx], linewidth=lw)

plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.title('Training Loss', fontsize=fs) 
ax = gca()
#plt.legend()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.show()
fig.savefig('conv_plotverlet.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) #to save the image
# Out:
#                               | running        | train          | valid
# epoch          time           | loss           | loss           | loss
# 0              0.0784         | 1.3420e-05     | 1.1859e-05     | 1.3552e-05
# 5              0.1076         | 8.1108e-06     | 7.7703e-06     | 5.9646e-06
# 10             0.1064         | 4.2175e-06     | 3.8041e-06     | 2.0724e-06
# 15             0.0917         | 1.7480e-06     | 1.5581e-06     | 4.3871e-07
# 20             0.0812         | 5.1377e-07     | 4.6008e-07     | 2.5804e-07
# 25             0.0823         | 2.4235e-07     | 2.3296e-07     | 1.4162e-07
# 30             0.0798         | 1.8601e-07     | 1.8120e-07     | 1.0871e-07
# 35             0.0863         | 1.5275e-07     | 1.4946e-07     | 9.0705e-08
# 40             0.0740         | 1.2583e-07     | 1.2325e-07     | 7.7634e-08
# 45             0.0788         | 1.0348e-07     | 1.0179e-07     | 6.6181e-08
# 50             0.0764         | 8.5064e-08     | 8.3504e-08     | 5.6123e-08
# 55             0.0791         | 7.0343e-08     | 6.8967e-08     | 4.7501e-08
# 60             0.0769         | 5.8473e-08     | 5.7250e-08     | 3.9629e-08
# 65             0.0768         | 4.8771e-08     | 4.7854e-08     | 3.2723e-08
# 70             0.0776         | 4.0931e-08     | 4.0052e-08     | 2.7042e-08
# 75             0.0758         | 3.4370e-08     | 3.3679e-08     | 2.2173e-08
# 80             0.0869         | 2.8854e-08     | 2.8305e-08     | 1.8362e-08
# 85             0.0754         | 2.4329e-08     | 2.3785e-08     | 1.5072e-08
# 90             0.0829         | 2.0521e-08     | 2.0010e-08     | 1.2746e-08
# 95             0.0762         | 1.7395e-08     | 1.6954e-08     | 1.0773e-08
# 100            0.0793         | 1.4826e-08     | 1.4702e-08     | 9.4350e-09
# 105            0.0773         | 1.2867e-08     | 1.2619e-08     | 8.4015e-09
# 110            0.0789         | 1.1327e-08     | 1.1208e-08     | 7.4353e-09
# 115            0.1099         | 1.0054e-08     | 9.9361e-09     | 6.6686e-09
# 120            0.1108         | 9.1067e-09     | 8.9805e-09     | 6.2624e-09
# 125            0.0776         | 8.3278e-09     | 8.2211e-09     | 5.6096e-09
# 130            0.0763         | 7.6228e-09     | 7.5774e-09     | 5.1647e-09
# 135            0.0778         | 7.1360e-09     | 7.1138e-09     | 5.1452e-09
# 140            0.0785         | 6.6454e-09     | 6.6219e-09     | 4.7587e-09
# 145            0.0796         | 6.2195e-09     | 6.1970e-09     | 4.1053e-09
# 150            0.0743         | 5.9327e-09     | 5.9287e-09     | 3.8085e-09
# 155            0.0774         | 5.5908e-09     | 5.6022e-09     | 3.6900e-09
# 160            0.0766         | 5.2656e-09     | 5.2277e-09     | 3.3963e-09
# 165            0.0771         | 5.0460e-09     | 4.9909e-09     | 3.2293e-09
# 170            0.0754         | 4.7849e-09     | 4.7522e-09     | 3.0298e-09
# 175            0.0800         | 4.6123e-09     | 4.5716e-09     | 2.8508e-09
# 180            0.0759         | 4.4222e-09     | 4.3452e-09     | 2.7036e-09
# 185            0.0752         | 4.2373e-09     | 4.2145e-09     | 2.6155e-09
# 190            0.0784         | 4.0846e-09     | 4.0739e-09     | 2.3606e-09
# 195            0.0760         | 3.8614e-09     | 3.8643e-09     | 2.1828e-09
# 200            0.0818         | 3.7700e-09     | 3.7207e-09     | 2.1734e-09
# 205            0.0785         | 3.6066e-09     | 3.6037e-09     | 2.0204e-09
# 210            0.0778         | 3.5946e-09     | 3.5350e-09     | 1.9706e-09
# 215            0.0804         | 3.3761e-09     | 3.3069e-09     | 1.8061e-09
# 220            0.1229         | 3.2607e-09     | 3.2375e-09     | 1.7715e-09
# 225            0.1106         | 3.2190e-09     | 3.2333e-09     | 1.7091e-09
# 230            0.1145         | 3.0453e-09     | 3.0982e-09     | 1.6287e-09
# 235            0.0802         | 2.8952e-09     | 2.9985e-09     | 1.5263e-09
# 240            0.0816         | 2.8525e-09     | 3.1696e-09     | 1.5209e-09
# 245            0.0806         | 2.7801e-09     | 2.8048e-09     | 1.3483e-09
# 250            0.0822         | 2.6274e-09     | 2.5722e-09     | 1.3731e-09
# 255            0.0783         | 2.5437e-09     | 2.5267e-09     | 1.2780e-09
# 260            0.0763         | 2.4663e-09     | 2.3987e-09     | 1.2286e-09
# 265            0.0767         | 2.6011e-09     | 2.8995e-09     | 1.3981e-09
# 270            0.0744         | 2.3165e-09     | 2.3249e-09     | 1.1915e-09
# 275            0.0764         | 2.2593e-09     | 2.3088e-09     | 1.1263e-09
# 280            0.0744         | 2.2015e-09     | 2.1969e-09     | 1.0672e-09
# 285            0.0755         | 2.1457e-09     | 2.0881e-09     | 1.0499e-09
# 290            0.0767         | 2.0439e-09     | 2.1754e-09     | 1.0345e-09
# 295            0.0800         | 1.9974e-09     | 1.9431e-09     | 9.7528e-10
# 300            0.0767         | 1.9557e-09     | 1.9022e-09     | 9.7182e-10
# 305            0.0754         | 2.0160e-09     | 2.0751e-09     | 9.9624e-10
# 310            0.0803         | 1.8937e-09     | 1.8185e-09     | 9.2438e-10
# 315            0.0759         | 1.7863e-09     | 1.7659e-09     | 9.3326e-10
# 320            0.0815         | 1.7660e-09     | 1.7681e-09     | 9.9730e-10
# 325            0.0783         | 1.7105e-09     | 1.6811e-09     | 9.2677e-10
# 330            0.1120         | 1.6156e-09     | 1.5894e-09     | 8.4881e-10
# 335            0.1192         | 1.6232e-09     | 1.6646e-09     | 8.5515e-10
# 340            0.1002         | 1.6526e-09     | 1.6690e-09     | 9.1815e-10
# 345            0.0763         | 1.5502e-09     | 1.5204e-09     | 8.5092e-10
# 350            0.0778         | 1.4492e-09     | 1.4542e-09     | 8.2135e-10
# 355            0.0775         | 1.4826e-09     | 1.4810e-09     | 8.2143e-10
# 360            0.0767         | 1.3806e-09     | 1.3567e-09     | 7.3717e-10
# 365            0.0785         | 1.4107e-09     | 1.4309e-09     | 7.2882e-10
# 370            0.0745         | 1.3951e-09     | 1.3600e-09     | 7.7237e-10
# 375            0.0767         | 1.3999e-09     | 1.7261e-09     | 7.9616e-10
# 380            0.0808         | 1.3364e-09     | 1.4866e-09     | 7.9694e-10
# 385            0.0788         | 1.3964e-09     | 1.2347e-09     | 7.5117e-10
# 390            0.0812         | 1.2925e-09     | 1.2201e-09     | 7.4514e-10
# 395            0.0773         | 1.1449e-09     | 1.1411e-09     | 6.8848e-10
# 400            0.0791         | 1.1165e-09     | 1.1253e-09     | 6.8306e-10
# 405            0.0786         | 1.1078e-09     | 1.1069e-09     | 6.7569e-10
# 410            0.0793         | 1.1140e-09     | 1.0813e-09     | 6.6017e-10
# 415            0.0766         | 1.0468e-09     | 1.0457e-09     | 6.7550e-10
# 420            0.0805         | 1.1323e-09     | 1.1165e-09     | 6.9111e-10
# 425            0.0749         | 1.0752e-09     | 9.9733e-10     | 6.7112e-10
# 430            0.0808         | 1.0558e-09     | 1.2150e-09     | 7.7941e-10
# 435            0.0802         | 1.0092e-09     | 1.1155e-09     | 6.5679e-10
# 440            0.1133         | 1.0221e-09     | 1.1000e-09     | 6.4927e-10
# 445            0.1205         | 9.4227e-10     | 9.0789e-10     | 6.2213e-10
# 450            0.0769         | 9.1837e-10     | 9.4102e-10     | 6.5548e-10
# 455            0.0843         | 9.9960e-10     | 9.8848e-10     | 6.1125e-10
# 460            0.0784         | 8.4048e-10     | 8.4319e-10     | 6.1918e-10
# 465            0.0823         | 8.6902e-10     | 8.3639e-10     | 5.8959e-10
# 470            0.0737         | 8.7622e-10     | 8.3434e-10     | 5.9234e-10
# 475            0.0795         | 8.1104e-10     | 7.8735e-10     | 5.6598e-10
# 480            0.0783         | 8.1981e-10     | 7.8304e-10     | 5.7041e-10
# 485            0.0777         | 7.7466e-10     | 8.1856e-10     | 5.7592e-10
# 490            0.0848         | 8.4276e-10     | 7.8892e-10     | 5.4894e-10
# 495            0.0765         | 7.8198e-10     | 8.1583e-10     | 5.7690e-10
# Test Loss: 7.6357e-10
# Time:41.639987844000075

# %%
# Go back and solve the ODE, put info in sol array

xinit = x_train[0:1,:]
steps = 4001
h = stepSize
sol = torch.zeros(steps,8) #initialize
t_solspan = np.zeros(steps) #initialize
t=0

for i in range(steps): #for each step
  fb = f(xinit,do_gradient=True,do_hessian = False) #plug x_init

  y1 = stepSize*fb[1][:,3:5,0]  + xinit[:,1:3] 
  z1 = -1 * stepSize*fb[1][:,1:3,0] + xinit[:,3:5] 
  y2 = stepSize*fb[1][:,8:10,0]  + xinit[:,6:8] 
  z2 = -1 * stepSize*fb[1][:,6:8,0] + xinit[:,8:10]

  t = t + h
  t_solspan[i] = t
  xinit = torch.cat((xinit[0:1,0:1] + h, y1, z1, xinit[0:1,5:6] + h, y2, z2),dim=1)
  sol[i:i+1,:] =  torch.cat(( y1, z1, y2, z2),dim=1) #store in solutions
# t_solspan[1] = t

# %%
sol = sol.t().detach().numpy()
orbit_sol = np.ones((2,5,steps))
orbit_sol[0,1:5,:] = sol[:4,:]
orbit_sol[1,1:5,:] = sol[4:8,:]

# %%
#Here we are plotting our learned positions against the true positions

fs=15; tpad=6; lw=3; ms=30

plt.title('Verlet Learned Position Values', fontsize=fs)

#lines
plt.plot(t_solspan,orbit_sol[0][1,:], "k-",linewidth=lw,  color = "orange", label='Learned Body 1 Position'.format(i))
plt.plot(t_solspan,orbit_sol[1][1,:], "k-", linewidth=lw, color = "royalblue", label='Learned Body 2 Position'.format(i))

holder = 0

plt.plot(settings['t_eval'][:steps],orbit[0][1,:steps], "k-.", label='True Values')
plt.plot(settings['t_eval'][:steps],orbit[1][1,:steps], "k-.")

#labels
plt.xlabel('Time', fontsize=12) 
plt.ylabel('px', fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':10})

ax = gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('Verlet learned position.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-33-1aeff71eb847>:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(t_solspan,orbit_sol[0][1,:], "k-",linewidth=lw,  color = "orange", label='Learned Body 1 Position'.format(i))
# <ipython-input-33-1aeff71eb847>:9: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(t_solspan,orbit_sol[1][1,:], "k-", linewidth=lw, color = "royalblue", label='Learned Body 2 Position'.format(i))

# %%
#Plot the predicted Trajectories of our bodies
fs=15; tpad=6; lw=3; ms=30
rc('axes', linewidth=2)

plt.title('Verlet Trajectories', fontsize=fs, pad=tpad)
colors = ["orange", "royalblue"]
labels = ["Body 1", "Body 2"]
plt.xlabel('px', fontsize=12) 
plt.ylabel('qx', fontsize=12)


ax = gca()

for i, path in enumerate(orbit_sol):
    plt.plot(path[1], path[2], "k-", linewidth=lw, color = colors[i], label=labels[i].format(i))
for i, path in enumerate(orbit):
    plt.plot(path[1], path[2], "k:", linewidth=lw, label='ground truth'.format(i))
plt.legend(fontsize=7, loc='lower right', prop={'size':10})

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('Verlet Trajectories.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-34-96e9e205dbb0>:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(path[1], path[2], "k-", linewidth=lw, color = colors[i], label=labels[i].format(i))

# %%
print(real_etot)
# Out:
# [-0.27996238 -0.27998351 -0.28000375 ... -0.27545856 -0.27543518
#  -0.27541146]

# %%
#Plot the energy values


#lines
plt.plot(settings['t_eval'], potential_energy(orbit), 'k--',linewidth=lw,label='potential')
plt.plot(settings['t_eval'], kinetic_energy(orbit),'k:',linewidth=lw, label='kinetic')
plt.plot(settings['t_eval'], total_energy(orbit),  'k-.',linewidth=lw,label='total')
plt.plot(settings['t_eval'], real_ke,  label='Kinetic',color = 'blue')
plt.plot(settings['t_eval'], real_pe, label='Potential',color = "purple")
plt.plot(settings['t_eval'], real_etot,  label='Total',color = "red")


ax = gca()

#labels
plt.title('Verlet Energy', fontsize=fs, pad=tpad)
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Energy", fontsize=12)
plt.ylim(ymin, ymax)
plt.legend(fontsize=7, loc='best', prop={'size':10})

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(12)

plt.savefig('Verlet Energy.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)

# %%
plt.figure()
plt.title('Verlet Position Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'][:steps],(orbit[0][1,:steps]-orbit_sol[0][1,:])/orbit[0][1,:steps],linewidth=lw,label='Learned Body 1 Error'.format(i))
plt.plot(settings['t_eval'][:steps],(orbit[1][1,:steps]-orbit_sol[1][1,:])/orbit[1][1,:steps],linewidth=lw,label='Learned Body 2 Error'.format(i))
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyErrorPosition.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) 


pathOneOrbitSol = []
pathTwoOrbitSol = []
pathOneOrbit = []
pathTwoOrbit = []

for i, path in enumerate(orbit_sol):
    pathOneOrbitSol.append(path[1])
    pathTwoOrbitSol.append(path[2])
for i, path in enumerate(orbit):
    pathOneOrbit.append(path[1])
    pathTwoOrbit.append(path[2])

pathOneOrbitSol = np.array(pathOneOrbitSol)
pathTwoOrbitSol = np.array(pathTwoOrbitSol)
pathOneOrbit = np.array(pathOneOrbit)
pathTwoOrbit = np.array(pathTwoOrbit)

plt.figure()
plt.title('Verlet Trajectories Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'],np.abs(pathOneOrbitSol-pathOneOrbit)[0]/np.abs(pathOneOrbitSol)[0]+np.abs(pathOneOrbitSol-pathOneOrbit)[1]/np.abs(pathOneOrbitSol[1]),linewidth=lw,label='Trajectories Body 1 Error'.format(i))
plt.plot(settings['t_eval'],np.abs(pathTwoOrbitSol-pathTwoOrbit)[0]/np.abs(pathTwoOrbitSol)[0]+np.abs(pathTwoOrbitSol-pathTwoOrbit)[1]/np.abs(pathTwoOrbitSol)[1],linewidth=lw,label='Trajectories Body 2 Error'.format(i))
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyErrorTrajectories.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05) 

plt.figure()
plt.title('Verlet Energy Error', fontsize=fs, pad=tpad)
plt.plot(settings['t_eval'], (real_ke-kinetic_energy(orbit))/kinetic_energy(orbit),'k--', linewidth=lw, label='Kinetic Error', color = 'blue')
plt.plot(settings['t_eval'], (real_pe-potential_energy(orbit))/potential_energy(orbit),'k:', linewidth=lw, label='Potential Error' ,color = 'purple')
plt.plot(settings['t_eval'], (real_etot-total_energy(orbit))/total_energy(orbit),'k-.', linewidth=lw, label='Total Error',color = "red")
plt.xlabel('Time', fontsize=12) 
plt.ylabel("Error", fontsize=12)
plt.ylim(ymin, ymax)
plt.legend(fontsize=7, loc='lower right', prop={'size':12})
plt.savefig('2BodyErrorEnergy.png',dpi=600, bbox_inches = 'tight', pad_inches = 0.05)
# Out:
# <ipython-input-37-d17085bced45>:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_ke-kinetic_energy(orbit))/kinetic_energy(orbit),'k--', linewidth=lw, label='Kinetic Error', color = 'blue')
# <ipython-input-37-d17085bced45>:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k:" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_pe-potential_energy(orbit))/potential_energy(orbit),'k:', linewidth=lw, label='Potential Error' ,color = 'purple')
# <ipython-input-37-d17085bced45>:41: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(settings['t_eval'], (real_etot-total_energy(orbit))/total_energy(orbit),'k-.', linewidth=lw, label='Total Error',color = "red")
